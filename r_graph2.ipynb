# %%
dt<-read.csv('152385_merge.csv')
dt
# Out:
#    period     ratio     X1       X2
# 1  2017-11-22 100.00000 67.83133 81.36145
# 2  2017-11-23  42.87689 68.54430 77.82278
# 3  2017-11-24  41.01544 70.20374 79.83022
# 4  2017-11-25  92.64859 73.13503 81.78470
# 5  2017-11-26  46.47081 69.27966 78.06144
# 6  2017-11-27  28.40203 72.39583 82.05729
# 7  2017-11-28  23.51127 72.47788 81.27434
# 8  2017-11-29  25.34340 72.88274 81.67752
# 9  2017-11-30  21.39731 65.74803 72.33596
# 10 2017-12-01  20.59737 64.77273 70.90909
# 11 2017-12-02  28.86674 75.04092 82.42226
# 12 2017-12-03  23.75042 75.71429 82.63492
# 13 2017-12-04  14.54639 66.12245 68.65306
# 14 2017-12-05  12.14917 68.67470 76.68675
# 15 2017-12-06  10.65562 63.75000 71.81250
# 16 2017-12-07  10.24575 69.54887 74.06015
# 17 2017-12-08  13.13176 75.65789 80.26316
# 18 2017-12-09  20.05445 64.38356 74.42922
# 19 2017-12-10  14.71472 68.53933 76.59176
# 20 2017-12-11   9.23813 68.14815 75.92593
# 21 2017-12-12   7.80681 67.47573 70.58252
# 22 2017-12-13   7.67066 65.23810 74.28571
# 23 2017-12-14   6.12275 67.33333 74.00000
# 24 2017-12-15   6.36070 70.20202 76.16162
# 25 2017-12-16   8.55144 79.12088 78.90110
# 26 2017-12-17   9.04237 73.03922 80.78431
# 27 2017-12-18   5.06481 65.95745 74.46809
# 28 2017-12-19   4.52381 70.37037 79.07407
# 29 2017-12-20   3.44561 76.47059 81.56863
# 30 2017-12-21  11.11317 63.81579 71.05263
# 31 2017-12-22  18.70611 49.56140 60.78947

# %%
x<-dt$period
y1<-dt$ratio
y2<-dt$X1
y3<-dt$X2

# %%
plot(x, y1, type='p')
lines(x, y1)
points(x, y2, type='p', col="red")
lines(x, y2)
points(x, y3, type='p', col="blue")
lines(x, y3)
# Out:
# plot without title

# %%
points(x,y1, type = 'l', col = "Red") 
points(x,y2, type = 'l', col = "Blue")
# Out:
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
# Traceback:
#
# 1. points(x, y1, type = "l", col = "Red")
# 2. points.default(x, y1, type = "l", col = "Red")
# 3. plot.xy(xy.coords(x, y), type = type, ...)

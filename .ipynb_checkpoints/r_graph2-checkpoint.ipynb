# %%
dt<-read.csv('154272_merge.csv')
dt
# Out:
#    period     ratio     X1       X2
# 1  2017-11-29  62.27451 71.41454 84.10609
# 2  2017-11-30  71.95908 73.35938 89.04688
# 3  2017-12-01  57.50277 73.15436 87.09172
# 4  2017-12-02 100.00000 69.91758 81.34615
# 5  2017-12-03  66.99334 77.43106 88.37446
# 6  2017-12-04  54.05875 54.59459 67.83784
# 7  2017-12-05  48.89902 51.58730 68.88889
# 8  2017-12-06  56.71419 61.32075 67.35849
# 9  2017-12-07  44.25828 64.45783 67.71084
# 10 2017-12-08  40.75128 62.34568 74.81481
# 11 2017-12-09  54.16708 56.09756 72.68293
# 12 2017-12-10  39.20437 60.95238 71.14286
# 13 2017-12-11  17.43172 57.14286 72.67857
# 14 2017-12-12  18.61332 56.52174 69.34783
# 15 2017-12-13  24.79340 60.81081 74.05405
# 16 2017-12-14  26.39574 61.84211 67.63158
# 17 2017-12-15  16.94548 57.57576 74.54545
# 18 2017-12-16  18.27572 57.35294 75.00000
# 19 2017-12-17  13.40320 70.00000 73.75000
# 20 2017-12-18  10.02720 56.25000 74.37500
# 21 2017-12-19   8.70956 62.50000 72.50000
# ...

# %%
x<-dt$period
y1<-dt$ratio
y2<-dt$X1
y3<-dt$X2

# %%
plot(x, y1, type='p')
lines(x, y1)
points(x, y2, type='p', col="red")
lines(x, y2)
points(x, y3, type='p', col="blue")
lines(x, y3)
# Out:
# plot without title

# %%
points(x,y1, type = 'l', col = "Red") 
points(x,y2, type = 'l', col = "Blue")
# Out:
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
# Traceback:
#
# 1. points(x, y1, type = "l", col = "Red")
# 2. points.default(x, y1, type = "l", col = "Red")
# 3. plot.xy(xy.coords(x, y), type = type, ...)

# %%
analyze <- function(filename) {
    dat <- read.csv(file = filename, header = FALSE)
    x<-dt$period
    y1<-dt$ratio
    y2<-dt$X1
    y3<-dt$X2
    plot(x, y1, type='p')
    lines(x, y1)
    points(x, y2, type='p', col="red")
    lines(x, y2)
    points(x, y3, type='p', col="blue")
    lines(x, y3)
}

# %%
file_list <- list.files(pattern = "csv")
file_list
# Out:
#  [1] "100205_merge.csv" "116866_merge.csv" "125418_merge.csv" "125488_merge.csv"
#  [5] "134898_merge.csv" "134963_merge.csv" "144379_merge.csv" "152385_merge.csv"
#  [9] "154272_merge.csv" "154594_merge.csv" "155411_merge.csv" "155665_merge.csv"
# [13] "159037_merge.csv" "160399_merge.csv" "162932_merge.csv" "164335_merge.csv"
# [17] "164932_merge.csv" "166008_merge.csv" "166807_merge.csv" "169349_merge.csv"
# [21] "85579_merge.csv"

# %%
for (f in filenames) {
    print(f)
    dat <- read.csv(f,'rt')
    analyze(f)
}
# Out:
# [1] "116866_merge.csv"
# Error in !header: invalid argument type
# Traceback:
#
# 1. read.csv(f, "rt")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)

# %%
file_list <- list.files(pattern = "csv")
file_list
# Out:
#  [1] "100205_merge.csv" "116866_merge.csv" "125418_merge.csv" "125488_merge.csv"
#  [5] "134898_merge.csv" "134963_merge.csv" "144379_merge.csv" "152385_merge.csv"
#  [9] "154272_merge.csv" "154594_merge.csv" "155411_merge.csv" "155665_merge.csv"
# [13] "159037_merge.csv" "160399_merge.csv" "162932_merge.csv" "164335_merge.csv"
# [17] "164932_merge.csv" "166008_merge.csv" "166807_merge.csv" "169349_merge.csv"
# [21] "85579_merge.csv"

# %%
file_list <- list.files(pattern = "csv")
for(file in file_list){
    print(file)
    dat<-read.csv(file)
    x<-dt$period
    y1<-dt$ratio
    y2<-dt$X1
    y3<-dt$X2
    plot(x, y1, type='p')
    lines(x, y1)
    points(x, y2, type='p', col="red")
    lines(x, y2)
    points(x, y3, type='p', col="blue")
    lines(x, y3)
}
# Out:
# [1] "100205_merge.csv"
# [1] "106360_merge.csv"
# [1] "116866_merge.csv"
# [1] "125418_merge.csv"
# [1] "125488_merge.csv"
# [1] "134898_merge.csv"
# [1] "134963_merge.csv"
# [1] "144379_merge.csv"
# [1] "144975_merge.csv"
# [1] "151196_merge.csv"
# [1] "152385_merge.csv"
# [1] "154272_merge.csv"
# [1] "154594_merge.csv"
# [1] "155411_merge.csv"
# [1] "155665_merge.csv"
# [1] "158191_merge.csv"
# [1] "159037_merge.csv"
# [1] "160399_merge.csv"
# [1] "162932_merge.csv"
# [1] "163844_merge.csv"
# [1] "164335_merge.csv"
# [1] "164932_merge.csv"
# [1] "165722_merge.csv"
# [1] "166008_merge.csv"
# [1] "166807_merge.csv"
# [1] "168478_merge.csv"
# [1] "168501_merge.csv"
# [1] "169349_merge.csv"
# [1] "85579_merge.csv"
# plot without title
